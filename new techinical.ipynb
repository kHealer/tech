# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('country_vaccination_stats.csv')

# %%
df.head(10)
# Out:
#      country        date  daily_vaccinations   vaccines
# 0  Argentina  12/29/2020                 NaN  Sputnik V
# 1  Argentina  12/30/2020             15656.0  Sputnik V
# 2  Argentina  12/31/2020             15656.0  Sputnik V
# 3  Argentina    1/1/2021             11070.0  Sputnik V
# 4  Argentina    1/2/2021              8776.0  Sputnik V
# 5  Argentina    1/3/2021              7400.0  Sputnik V
# 6  Argentina    1/4/2021              6483.0  Sputnik V
# 7  Argentina    1/5/2021              7984.0  Sputnik V
# 8  Argentina    1/6/2021              8173.0  Sputnik V
# 9  Argentina    1/7/2021              8363.0  Sputnik V

# %%
df.shape
# Out:
# (1502, 4)

# %%
df.dtypes
# Out:
# country                object
# date                   object
# daily_vaccinations    float64
# vaccines               object
# dtype: object

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1497    False
# 1498    False
# 1499    False
# 1500    False
# 1501    False
# Length: 1502, dtype: bool

# %%
df.isnull().sum()
# Out:
# country                0
# date                   0
# daily_vaccinations    60
# vaccines               0
# dtype: int64

# %%
df['country'].count()
# Out:
# 1502

# %%
df.interpolate(method ='linear', limit_direction ='backward', inplace=True)

# %%
df.isnull().sum()
# Out:
# country               0
# date                  0
# daily_vaccinations    0
# vaccines              0
# dtype: int64

# %%
df.sort_values('daily_vaccinations', ascending=False).head(3)
# Out:
#             country       date  daily_vaccinations                  vaccines
# 1458  United States  1/25/2021           1126251.0  Moderna, Pfizer/BioNTech
# 1457  United States  1/24/2021           1122182.0  Moderna, Pfizer/BioNTech
# 1456  United States  1/23/2021           1057387.0  Moderna, Pfizer/BioNTech

# %%
df['daily_vaccinations'] = df['daily_vaccinations'].astype('int')

# %%
df
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020               15656
# 1     Argentina  12/30/2020               15656
# 2     Argentina  12/31/2020               15656
# 3     Argentina    1/1/2021               11070
# 4     Argentina    1/2/2021                8776
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021               11105
# 1498      Wales   1/21/2021               12318
# 1499      Wales   1/22/2021               15148
# 1500      Wales   1/23/2021               17371
# 1501      Wales   1/24/2021               17063
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
df1 = df.groupby(['country']).max('daily_vacciantions')

# %%
df1
# Out:
#                       daily_vaccinations
# country
# Argentina                          15656
# Austria                            12552
# Bahrain                            11106
# Belgium                            13135
# Brazil                             99928
# Bulgaria                           51408
# Canada                             39910
# Chile                              18477
# China                             714286
# Costa Rica                        357263
# Croatia                             3346
# Cyprus                              1587
# Czechia                            11220
# Denmark                            11022
# Ecuador                             2273
# England                           317419
# Estonia                           158864
# Finland                             8012
# France                             87584
# Germany                            87377
# Gibraltar                          44201
# Greece                             13165
# ...

# %%
df1.sort_values('daily_vaccinations', ascending=False).head(3)
# Out:
#                daily_vaccinations
# country
# United States             1126251
# China                      714286
# Wales                      564224

# %%
df
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020               15656
# 1     Argentina  12/30/2020               15656
# 2     Argentina  12/31/2020               15656
# 3     Argentina    1/1/2021               11070
# 4     Argentina    1/2/2021                8776
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021               11105
# 1498      Wales   1/21/2021               12318
# 1499      Wales   1/22/2021               15148
# 1500      Wales   1/23/2021               17371
# 1501      Wales   1/24/2021               17063
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
total = df.loc[df['date'] == '1/6/2021', 'daily_vaccinations'].sum()

# %%
total
# Out:
# 1511575
